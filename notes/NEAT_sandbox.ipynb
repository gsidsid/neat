# %%
import fitsio
import numpy as np
import matplotlib.pyplot as plt
from fitsio import FITS,FITSHDR

# %%
filename='geodss/data/g19960418/flats/96_04_18a_20secnrm_flat.fit'
data = fitsio.read(filename)

# %%
len(data)
# Out:
# 4080

# %%
fit_tmp=fitsio.FITS(filename)
print(fit_tmp)
# Out:
#   file: geodss/data/g19960418/flats/96_04_18a_20secnrm_flat.fit
#   mode: READONLY
#   extnum hdutype         hduname[v]
#   0      IMAGE_HDU

# %%
img=numpy.arange(2*3,dtype='i4').reshape(2,3)

# %%
# read the image from extension zero
img = fit_tmp[0].read()
img = fit_tmp[0][:,:]
img = fit_tmp[0][2053:4080, 2050:4080]

# %%
arr = np.asarray(img)
plt.imshow(arr)
plt.show()

# %%
fits=fitsio.FITS(filename)

# %%
fitsio.read(filename, header=True,iter_row_buffer=1000)
# Out:
# (array([[65535.88 , 65536.   , 65532.36 , ..., 65533.824, 65535.484,
#          65536.125],
#         [65535.85 , 65536.   , 65542.38 , ..., 65536.016, 65535.906,
#          65536.11 ],
#         [65535.867, 65536.   , 65541.875, ..., 65544.2  , 65535.906,
#          65536.11 ],
#         ...,
#         [65535.863, 65536.   , 65540.58 , ..., 65545.3  , 65536.   ,
#          65535.883],
#         [65535.91 , 65536.   , 65540.39 , ..., 65541.586, 65536.   ,
#          65535.906],
#         [65535.867, 65536.   , 65532.934, ..., 65533.54 , 65535.996,
#          65535.96 ]], dtype=float32),
#  SIMPLE  =                    T / Fits standard
#  BITPIX  =                  -32 / Bits per pixel
#  NAXIS   =                    2 / Number of axes
#  NAXIS1  =                 4080 / Axis length
#  NAXIS2  =                 4080 / Axis length
#  EXTEND  =                    F / File may contain extensions
#  ORIGIN  = 'NOAO-IRAF FITS Image Kernel December 2001' / FITS file originator
# ...
