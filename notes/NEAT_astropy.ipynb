# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
f='geodss/data/g19960418/flats/96_04_18a_20secnrm_flat.fit'
hdulist = fits.open(f)

# %%
hdulist.info()
# Out:
# Filename: geodss/data/g19960418/flats/96_04_18a_20secnrm_flat.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     144   (4080, 4080)   float32

# %%
# Primary HDU Access
hdu = hdulist[0]

# %%
hdu.header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 4080 / Axis length
# NAXIS2  =                 4080 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel December 2001' / FITS file originator
# DATE    = '2013-07-18T19:36:48'
# IRAF-TLM= '2013-08-21T17:27:04'
# DATE-OBS= '1996-04-18T06:42:13'
# OBJECT  = 'SKY FIELD'          /Object name
# TELESCOP= 'GEODSS1 '
# OBSERVAT= 'GEODSS - HALEAKALA' /Observatory
# OBSERVER= 'NOT_AVAILABLE'      /Observer
# OBSLAT  =            20.708010 /Observatory Latitude
# OBSLONG =           203.742400 /Observatory Longitude
# OBSALT  =          3040.350000 /Observatory Altitude (meters)
# INSTRUME= 'NEAT4   '
# GAIN    =             1.900000 /electron-hole pairs per adu
# TEMP    =            -1.173460 /CCD temperature reading
# ...

# %%
# Display dark
plt.imshow(hdu.data[:,:], origin='lower')
